# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiatanzeel33/assign-4new/blob/main/02_intermediate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def play_round():
    """Plays a single round of the High-Low game."""
    your_number = random.randint(1, 100)
    computer_number = random.randint(1, 100)
    print(f"Your number is {your_number}")
    guess = input("Do you think your number is higher or lower than the computer's?: ").lower()

    if guess == "higher":
        if your_number > computer_number:
            print(f"You were right! The computer's number was {computer_number}")
            return 1
        else:
            print(f"Aww, that's incorrect. The computer's number was {computer_number}")
            return 0
    elif guess == "lower":
        if your_number < computer_number:
            print(f"You were right! The computer's number was {computer_number}")
            return 1
        else:
            print(f"Aww, that's incorrect. The computer's number was {computer_number}")
            return 0
    else:
        print("Invalid guess. Please enter 'higher' or 'lower'.")
        return 0

def main():
    """Runs the High-Low game for a fixed number of rounds."""
    print("Welcome to the High-Low Game!")
    print("--------------------------------")
    total_rounds = 5
    your_score = 0

    for round_num in range(1, total_rounds + 1):
        print(f"\nRound {round_num}")
        score = play_round()
        your_score += score
        print(f"Your score is now {your_score}")

    print("\nThanks for playing!")

if __name__ == "__main__":
    main()
# Out:
# Welcome to the High-Low Game!
# --------------------------------
#
# Round 1
# Your number is 43
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 15
# Your score is now 1
#
# Round 2
# Your number is 4
# Do you think your number is higher or lower than the computer's?: lower
# You were right! The computer's number was 76
# Your score is now 2
#
# Round 3
# Your number is 49
# Do you think your number is higher or lower than the computer's?: higher
# Aww, that's incorrect. The computer's number was 91
# Your score is now 2
#
# Round 4
# Your number is 43
# Do you think your number is higher or lower than the computer's?: higher
# Aww, that's incorrect. The computer's number was 69
# Your score is now 2
#
# Round 5
# Your number is 45
# Do you think your number is higher or lower than the computer's?: lower
# You were right! The computer's number was 51
# Your score is now 3
#
# Thanks for playing!

# %%
import random

def play_round():
    """Plays a single round of the High-Low game."""
    your_number = random.randint(1, 100)
    computer_number = random.randint(1, 100)
    print(f"The computer's number is {computer_number}")  # Print computer's number for testing
    print(f"Your number is {your_number}")
    guess = input("Do you think your number is higher or lower than the computer's?: ").lower()

    if guess == "higher":
        if your_number > computer_number:
            print("You were right!")
            return 1
        else:
            print("Aww, that's incorrect.")
            return 0
    elif guess == "lower":
        if your_number < computer_number:
            print("You were right!")
            return 1
        else:
            print("Aww, that's incorrect.")
            return 0
    else:
        print("Invalid guess. Please enter 'higher' or 'lower'.")
        return 0

def main():
    """Runs the High-Low game for a fixed number of rounds."""
    print("Welcome to the High-Low Game!")
    print("--------------------------------")
    total_rounds = 5
    your_score = 0

    for round_num in range(1, total_rounds + 1):
        print(f"\nRound {round_num}")
        score = play_round()
        your_score += score
        print(f"Your score is now {your_score}")

    print("\nThanks for playing!")

if __name__ == "__main__":
    main()
# Out:
# Welcome to the High-Low Game!
# --------------------------------
#
# Round 1
# The computer's number is 54
# Your number is 33
# Do you think your number is higher or lower than the computer's?: lower
# You were right!
# Your score is now 1
#
# Round 2
# The computer's number is 10
# Your number is 6
# Do you think your number is higher or lower than the computer's?: lower
# You were right!
# Your score is now 2
#
# Round 3
# The computer's number is 73
# Your number is 92
# Do you think your number is higher or lower than the computer's?: higher
# You were right!
# Your score is now 3
#
# Round 4
# The computer's number is 87
# Your number is 4
# Do you think your number is higher or lower than the computer's?: lower
# You were right!
# Your score is now 4
#
# Round 5
# The computer's number is 30
# Your number is 65
# Do you think your number is higher or lower than the computer's?: higher
# You were right!
# Your score is now 5
#
# Thanks for playing!

# %%
import random

def play_round():
    """Plays a single round of the High-Low game."""
    your_number = random.randint(1, 100)
    computer_number = random.randint(1, 100)
    print(f"The computer's number is {computer_number}")  # Print computer's number for testing
    print(f"Your number is {your_number}")
    guess = input("Do you think your number is higher or lower than the computer's?: ").lower()

    if guess == "higher":
        if your_number > computer_number:
            print(f"You were right! The computer's number was {computer_number}")
            return 1
        else:
            print(f"Aww, that's incorrect. The computer's number was {computer_number}")
            return 0
    elif guess == "lower":
        if your_number < computer_number:
            print(f"You were right! The computer's number was {computer_number}")
            return 1
        else:
            print(f"Aww, that's incorrect. The computer's number was {computer_number}")
            return 0
    else:
        print("Invalid guess. Please enter 'higher' or 'lower'.")
        return 0

def main():
    """Runs the High-Low game for a fixed number of rounds."""
    print("Welcome to the High-Low Game!")
    print("--------------------------------")
    total_rounds = 5
    your_score = 0

    for round_num in range(1, total_rounds + 1):
        print(f"\nRound {round_num}")
        score = play_round()
        your_score += score
        print(f"Your score is now {your_score}")

    print("\nThanks for playing!")

if __name__ == "__main__":
    main()
# Out:
# Welcome to the High-Low Game!
# --------------------------------
#
# Round 1
# The computer's number is 2
# Your number is 21
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 2
# Your score is now 1
#
# Round 2
# The computer's number is 51
# Your number is 30
# Do you think your number is higher or lower than the computer's?: lower
# You were right! The computer's number was 51
# Your score is now 2
#
# Round 3
# The computer's number is 78
# Your number is 84
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 78
# Your score is now 3
#
# Round 4
# The computer's number is 24
# Your number is 92
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 24
# Your score is now 4
#
# Round 5
# The computer's number is 36
# Your number is 80
# ...

# %%
import random

NUM_ROUNDS = 5  # You can adjust the number of rounds here

def play_round():
    """Plays a single round of the High-Low game."""
    your_number = random.randint(1, 100)
    computer_number = random.randint(1, 100)
    print(f"Your number is {your_number}")
    guess = input("Do you think your number is higher or lower than the computer's?: ").lower()

    if guess == "higher":
        if your_number > computer_number:
            print(f"You were right! The computer's number was {computer_number}")
            return 1
        else:
            print(f"Aww, that's incorrect. The computer's number was {computer_number}")
            return 0
    elif guess == "lower":
        if your_number < computer_number:
            print(f"You were right! The computer's number was {computer_number}")
            return 1
        else:
            print(f"Aww, that's incorrect. The computer's number was {computer_number}")
            return 0
    else:
        print("Invalid guess. Please enter 'higher' or 'lower'.")
        return 0

def main():
    """Runs the High-Low game for a fixed number of rounds."""
    print("Welcome to the High-Low Game!")
    print("--------------------------------")
    your_score = 0

    for round_num in range(1, NUM_ROUNDS + 1):
        print(f"\nRound {round_num}")
        score = play_round()
        your_score += score
        print(f"Your score is now {your_score}")
        print()  # Add a blank line to separate rounds

    print("Thanks for playing!")
    print(f"Your final score is: {your_score} out of {NUM_ROUNDS}")

if __name__ == "__main__":
    main()
# Out:
# Welcome to the High-Low Game!
# --------------------------------
#
# Round 1
# Your number is 17
# Do you think your number is higher or lower than the computer's?: lower
# You were right! The computer's number was 47
# Your score is now 1
#
#
# Round 2
# Your number is 69
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 53
# Your score is now 2
#
#
# Round 3
# Your number is 55
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 36
# Your score is now 3
#
#
# Round 4
# Your number is 80
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 79
# Your score is now 4
#
#
# Round 5
# Your number is 65
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 50
# Your score is now 5
#
# Thanks for playing!
# ...

# %%
import random

NUM_ROUNDS = 5  # You can adjust the number of rounds here

def play_round():
    """Plays a single round of the High-Low game."""
    your_number = random.randint(1, 100)
    computer_number = random.randint(1, 100)
    print(f"Your number is {your_number}")

    while True:
        guess = input("Do you think your number is higher or lower than the computer's?: ").lower()
        if guess in ["higher", "lower"]:
            break
        else:
            print("Invalid input. Please enter 'higher' or 'lower'.")

    if guess == "higher":
        if your_number > computer_number:
            print(f"You were right! The computer's number was {computer_number}")
            return 1
        else:
            print(f"Aww, that's incorrect. The computer's number was {computer_number}")
            return 0
    elif guess == "lower":
        if your_number < computer_number:
            print(f"You were right! The computer's number was {computer_number}")
            return 1
        else:
            print(f"Aww, that's incorrect. The computer's number was {computer_number}")
            return 0

def main():
    """Runs the High-Low game for a fixed number of rounds and tracks the score."""
    print("Welcome to the High-Low Game!")
    print("--------------------------------")
    your_score = 0

    for round_num in range(1, NUM_ROUNDS + 1):
        print(f"\nRound {round_num}")
        score = play_round()
        your_score += score
        print(f"Your score is now {your_score}")
        print()  # Add a blank line to separate rounds

    print("Thanks for playing!")
    print(f"Your final score is: {your_score} out of {NUM_ROUNDS}")

if __name__ == "__main__":
    main()
# Out:
# Welcome to the High-Low Game!
# --------------------------------
#
# Round 1
# Your number is 95
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 53
# Your score is now 1
#
#
# Round 2
# Your number is 86
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 61
# Your score is now 2
#
#
# Round 3
# Your number is 89
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 69
# Your score is now 3
#
#
# Round 4
# Your number is 86
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 57
# Your score is now 4
#
#
# Round 5
# Your number is 16
# Do you think your number is higher or lower than the computer's?: lower
# You were right! The computer's number was 83
# Your score is now 5
#
# Thanks for playing!
# ...

# %%
import random
import math

NUM_ROUNDS = 5  # You can adjust the number of rounds here

def play_round():
    """Plays a single round of the High-Low game."""
    your_number = random.randint(1, 100)
    computer_number = random.randint(1, 100)
    print(f"Your number is {your_number}")

    while True:
        guess = input("Do you think your number is higher or lower than the computer's?: ").lower()
        if guess in ["higher", "lower"]:
            break
        else:
            print("Invalid input. Please enter 'higher' or 'lower'.")

    if guess == "higher":
        if your_number > computer_number:
            print(f"You were right! The computer's number was {computer_number}")
            return 1
        else:
            print(f"Aww, that's incorrect. The computer's number was {computer_number}")
            return 0
    elif guess == "lower":
        if your_number < computer_number:
            print(f"You were right! The computer's number was {computer_number}")
            return 1
        else:
            print(f"Aww, that's incorrect. The computer's number was {computer_number}")
            return 0

def main():
    """Runs the High-Low game for a fixed number of rounds and tracks the score."""
    print("Welcome to the High-Low Game!")
    print("--------------------------------")
    your_score = 0

    for round_num in range(1, NUM_ROUNDS + 1):
        print(f"\nRound {round_num}")
        score = play_round()
        your_score += score
        print(f"Your score is now {your_score}")
        print()  # Add a blank line to separate rounds

    print("Thanks for playing!")
    print(f"Your final score is: {your_score} out of {NUM_ROUNDS}")

    if your_score == NUM_ROUNDS:
        print("Wow! You played perfectly!")
    elif your_score >= math.floor(NUM_ROUNDS / 2):
        print("Good job, you played really well!")
    else:
        print("Better luck next time!")

if __name__ == "__main__":
    main()
# Out:
# Welcome to the High-Low Game!
# --------------------------------
#
# Round 1
# Your number is 20
# Do you think your number is higher or lower than the computer's?: lower
# You were right! The computer's number was 97
# Your score is now 1
#
#
# Round 2
# Your number is 83
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 25
# Your score is now 2
#
#
# Round 3
# Your number is 26
# Do you think your number is higher or lower than the computer's?: lower
# You were right! The computer's number was 80
# Your score is now 3
#
#
# Round 4
# Your number is 80
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 45
# Your score is now 4
#
#
# Round 5
# Your number is 78
# Do you think your number is higher or lower than the computer's?: lower
# Aww, that's incorrect. The computer's number was 2
# Your score is now 4
#
# Thanks for playing!
# ...
